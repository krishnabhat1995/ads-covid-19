# %% [markdown]
# ![stages_EDS.PNG](attachment:stages_EDS.PNG)

# %% [markdown]
# # Business Understanding

# %% [markdown]
# The following objectives are aimed at during the course of this project
#
# 1. Plotting the spread of coronavirus in different countries
# 2. Plotting doubling rates
# 3. Simulating the spread using SIR model in Japan

# %% [markdown]
# # Goals

# %% [markdown]
# 1. We would like to understand the data quality
# 2. Everything should be automated as much as possible: how many clicks do we need to execute the full pipeline

# %% [markdown]
# # Constraints

# %% [markdown]
# Each notebook should be left clean and ready for full execution
